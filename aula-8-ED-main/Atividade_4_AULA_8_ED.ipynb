# %%
import networkx as nx
import matplotlib.pyplot as plt

# Criar um grafo simples
G = nx.Graph()

# Adicionar vértice / nós ()
G.add_nodes_from(['V0', 'V1', 'V2', 'V3', 'V4'])

# %%
# Linkar as Arestas (conexões)
G.add_edges_from([
    ('V0', 'V1'),
    ('V4', 'V3'),
    ('V1', 'V3'),
    ('V1', 'V2'),
    ('V3', 'V2'),])

# %%
print(f"Nós do grafo: {G.nodes()}")
print(f"Arestas do grafro: {G.edges()}")
print(f"Contando o num de Nós: {G.number_of_nodes()}")
print(f"Contando o num de Arestas: {G.number_of_edges()}")
# Out:
# Nós do grafo: ['V0', 'V1', 'V2', 'V3', 'V4']
# Arestas do grafro: [('V0', 'V1'), ('V1', 'V3'), ('V1', 'V2'), ('V2', 'V3'), ('V3', 'V4')]
# Contando o num de Nós: 5
# Contando o num de Arestas: 5

# %%
pos = nx.spring_layout(G, seed=42)

nx.draw(G, pos, with_labels= True, node_color='lightblue',
        font_weight='bold',node_size=700, font_size=10)

plt.title('Representação em Grafo simples')
plt.show()
